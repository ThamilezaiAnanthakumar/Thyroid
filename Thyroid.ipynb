# %% [markdown]
# <a href="https://colab.research.google.com/github/ThamilezaiAnanthakumar/Thyroid/blob/main/Thyroid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Data Collection and Preprocessing

# %%
thyroid_data=pd.read_csv('/content/Thyroid_Diff.csv')

# %%
thyroid_data.head()
# Out:
#    Age Gender Smoking Hx Smoking Hx Radiothreapy  ...   N   M Stage       Response Recurred
# 0   27      F      No         No              No  ...  N0  M0     I  Indeterminate       No
# 1   34      F      No        Yes              No  ...  N0  M0     I      Excellent       No
# 2   30      F      No         No              No  ...  N0  M0     I      Excellent       No
# 3   62      F      No         No              No  ...  N0  M0     I      Excellent       No
# 4   62      F      No         No              No  ...  N0  M0     I      Excellent       No
#
# [5 rows x 17 columns]

# %%
thyroid_data.tail()
# Out:
#      Age Gender Smoking Hx Smoking Hx Radiothreapy  ...    N   M Stage                Response Recurred
# 378   72      M     Yes        Yes             Yes  ...  N1b  M1   IVB  Biochemical Incomplete      Yes
# 379   81      M     Yes         No             Yes  ...  N1b  M1   IVB   Structural Incomplete      Yes
# 380   72      M     Yes        Yes              No  ...  N1b  M1   IVB   Structural Incomplete      Yes
# 381   61      M     Yes        Yes             Yes  ...  N1b  M0   IVA   Structural Incomplete      Yes
# 382   67      M     Yes         No              No  ...  N1b  M0   IVA   Structural Incomplete      Yes
#
# [5 rows x 17 columns]

# %%
thyroid_data.shape
# Out:
# (383, 17)

# %%
thyroid_data.describe()# only age is in number
# Out:
#               Age
# count  383.000000
# mean    40.866841
# std     15.134494
# min     15.000000
# 25%     29.000000
# 50%     37.000000
# 75%     51.000000
# max     82.000000

# %%
thyroid_data.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Smoking                 0
# Hx Smoking              0
# Hx Radiothreapy         0
# Thyroid Function        0
# Physical Examination    0
# Adenopathy              0
# Pathology               0
# Focality                0
# Risk                    0
# T                       0
# N                       0
# M                       0
# Stage                   0
# Response                0
# Recurred                0
# dtype: int64

# %% [markdown]
# # Lable Encoding
